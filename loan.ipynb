# %% [markdown]
# ## Importation des bibliothèques nécessaires pour le traitement des données et la visualisation
#
# Dans cette section, nous aborderons les bibliothèques nécessaires pour le traitement et la visualisation des données.
#
# ### Bibliothèques Requises
#
# - **Pandas** : Pandas est une puissante bibliothèque de manipulation de données.
# - **Matplotlib** : Matplotlib est une bibliothèque de traçage polyvalente.
# - **Seaborn** : Seaborn est une bibliothèque de visualisation de données statistiques.
# - **NumPy** : NumPy est un package fondamental pour le calcul scientifique.
#
# Importons ces bibliothèques :
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
import sklearn

# %%
# Les avertissements futurs sont des messages qui peuvent être affichés lors de l'utilisation de certaines fonctions ou bibliothèques.
# Dans certains cas, ces avertissements peuvent être inutiles ou gêners lors de l'exécution de votre code.
# La fonction warnings.simplefilter(action= "ignore",category=FutureWarning) permet d'ignorer ces avertissements futurs pour améliorer la lisibilité et la fluidité de votre code.
import warnings
warnings.simplefilter(action= "ignore",category=FutureWarning)

# %%
# La fonction pd.read_csv("loan_data.csv") permet de charger un fichier CSV (comma-separated values) et de le convertir en un DataFrame pandas.
df =pd.read_csv("loan_data.csv")

# %%
# Cette fonction est utile pour visualiser rapidement les premières lignes du DataFrame et pour vérifier que le chargement du fichier CSV a été effectué correctement.
display(df)
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
# La fonction df.info() permet d'obtenir une description détaillée des colonnes du DataFrame df.
# Cette fonction retourne des informations sur le type de chaque colonne, le nombre de valeurs manquantes, la valeur minimale, la valeur maximale, la valeur médiane, la valeur moyenne, etc.
# Cette fonction est utile pour comprendre les caractéristiques des données et pour identifier les colonnes qui peuvent nécessiter un traitement supplémentaire.
df.shape
# Out:
# (9578, 14)

# %%
# La fonction df.describe() retourne des statistiques résumées des colonnes du DataFrame df.
# Cette fonction calcule la valeur minimale, la valeur maximale, la valeur médiane, la valeur moyenne, et le quartile 1 et 3 pour chaque colonne.
# Cette fonction est utile pour obtenir un aperçu rapide des caractéristiques des données et pour identifier les colonnes qui peuvent nécessiter un traitement supplémentaire.
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
# Il donne des informations sur l'index, les types de données des colonnes, le nombre de valeurs non nulles.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
#recuperation de nombre d'occurrence des valeurs sur la columne de "credit.policy"
df['credit.policy'].value_counts()
# Out:
# credit.policy
# 1    7710
# 0    1868
# Name: count, dtype: int64

# %%
# La fonction sns.countplot(x="credit.policy",data=df, palette="YlGnBu") permet de créer un graphique de type "bar chart" qui représente le nombre d'occurrences de chaque valeur dans la colonne "credit.policy" du DataFrame df.
sns.countplot(x="credit.policy",data=df, palette="YlGnBu")
plt.show()

# %%
sns.countplot(x="credit.policy", hue="purpose", data=df)
plt.show()

# %%
# La fonction df['purpose'].value_counts() retourne les elemenet et leur occurence dans la colonne "purpose" du DataFrame df.
df['purpose'].value_counts()
# Out:
# purpose
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,4))
sns.countplot(x="purpose",data=df, palette="Reds")
plt.show()

# %%
# La fonction df.isnull().sum() retourne le nombre total de valeurs manquantes dans chaque colonne du DataFrame df.
df.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
# La fonction LabelEncoder() est une fonction de transformation de données qui permet de convertir des valeurs catégorielles en valeurs numériques.
from sklearn.preprocessing import LabelEncoder

# %%
#initialisation LabelEncouder()
label_en= LabelEncoder()

# %%
# Dans cette ligne de code, on utilise cette fonction pour convertir les valeurs de la colonne "purpose" du DataFrame df en valeurs numériques.
df['purpose']= label_en.fit_transform(df['purpose'])

# %%
df.head()
# Out:
#    credit.policy  purpose  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1        2    0.1189       829.10       11.350407  19.48   737
# 1              1        1    0.1071       228.22       11.082143  14.29   707
# 2              1        2    0.1357       366.86       10.373491  11.63   682
# 3              1        2    0.1008       162.34       11.350407   8.10   712
# 4              1        1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid
# 0        0               0
# ...

# %%
df["purpose"].value_counts()
# Out:
# purpose
# 2    3957
# 0    2331
# 1    1262
# 4     629
# 6     619
# 5     437
# 3     343
# Name: count, dtype: int64

# %%
# Cette fonction est utile pour identifier les doublons dans les données et pour éliminer les doublons si nécessaire.
dp = df.duplicated().sum()
print("nombre des valeur:",dp)
# Out:
# nombre des valeur: 0

# %%
df['credit.policy'].value_counts()
# Out:
# credit.policy
# 1    7710
# 0    1868
# Name: count, dtype: int64

# %% [markdown]
# ## les données sont fortement déséquilibrées
# ## separez le dataframe en deux data.frame minority 0 et majority 1

# %%
majority=df[df['credit.policy']==1]
minority=df[df['credit.policy']==0]

# %%
majority_sample=majority.sample(n=1868)

# %% [markdown]
# ## la concatination de majority sample avec minority

# %%
new_df=pd.concat([majority_sample,minority],axis=0)
display(new_df)
# Out:
#       credit.policy  purpose  int.rate  installment  log.annual.inc    dti  \
# 3936              1        1    0.1126        87.09       10.778956  20.80
# 2556              1        2    0.1505       381.61       10.463103   7.78
# 7286              1        3    0.0788       375.37       10.596635  14.79
# 462               1        0    0.0951       640.76       11.289782   0.22
# 2687              1        0    0.1474       386.82       11.063508  16.21
# ...             ...      ...       ...          ...             ...    ...
# 9573              0        0    0.1461       344.76       12.180755  10.39
# 9574              0        0    0.1253       257.70       11.141862   0.21
# 9575              0        2    0.1071        97.81       10.596635  13.09
# 9576              0        4    0.1600       351.58       10.819778  19.18
# 9577              0        2    0.1392       853.43       11.264464  16.28
#
# ...

# %%
new_df.shape
# Out:
# (3736, 14)

# %% [markdown]
# ## On a maintenant une data set équilibrée.

# %%
corr= df.corr()
corr
# Out:
#                    credit.policy   purpose  int.rate  installment  \
# credit.policy           1.000000  0.017569 -0.294089     0.058770
# purpose                 0.017569  1.000000  0.117067     0.154827
# int.rate               -0.294089  0.117067  1.000000     0.276140
# installment             0.058770  0.154827  0.276140     1.000000
# log.annual.inc          0.034906  0.088958  0.056383     0.448102
# dti                    -0.090901 -0.053279  0.220006     0.050202
# fico                    0.348319  0.057337 -0.714821     0.086039
# days.with.cr.line       0.099026  0.047526 -0.124022     0.183297
# revol.bal              -0.187518  0.042364  0.092527     0.233625
# revol.util             -0.104095 -0.062947  0.464837     0.081356
# inq.last.6mths         -0.535511  0.037516  0.202780    -0.010419
# delinq.2yrs            -0.076318 -0.011701  0.156079    -0.004368
# pub.rec                -0.054243  0.004793  0.098162    -0.032760
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr,cmap="RdBu",vmin=-1,vmax=1,annot=True)
# Out:
# <Axes: >

# %%
new_df['credit.policy'].value_counts()
# Out:
# credit.policy
# 1    1868
# 0    1868
# Name: count, dtype: int64

# %% [markdown]
# ## Target Variable Splitting (cible)

# %%
x = new_df.drop('credit.policy', axis = 1) 
y = new_df['credit.policy']

# %%
from sklearn import preprocessing
pre_process = preprocessing.StandardScaler().fit(x)
x_transform = pre_process.fit_transform(x)

# %%
# Use x and y variables to split the training data into train and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_transform, y, test_size = .15, random_state=0)

# %% [markdown]
# # 1. LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
print('Logistic Regression')
# Create instance of model
log_reg = LogisticRegression()

# Pass training data into model
log_reg.fit(x_train, y_train)
# Out:
# Logistic Regression
# LogisticRegression()

# %% [markdown]
# ## Model Evaluation
# ### Logistic regression

# %%
from sklearn.metrics import accuracy_score
y_pred_log_reg = log_reg.predict(x_test)

print('Logistic Regression')
# Accuracy
print('---'*30)
log_reg_accuracy = round(accuracy_score(y_test, y_pred_log_reg)*100,2)
print('Accuracy', log_reg_accuracy,'%')
# Out:
# Logistic Regression
# ------------------------------------------------------------------------------------------
# Accuracy 83.96 %

# %% [markdown]
# ### precision_score , recall_score ,confusion_matrix

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix
# Calculate precision and recall
precision = precision_score(y_test, y_pred_log_reg)
recall = recall_score(y_test, y_pred_log_reg)

# Print the results
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print("--"*30)
# Calculate confusion matrix
confusion = confusion_matrix(y_test, y_pred_log_reg)
print(confusion)
sns.heatmap(confusion, annot=True, fmt="d")
# Out:
# Precision: 0.84
# Recall: 0.85
# ------------------------------------------------------------
# [[221  46]
#  [ 44 250]]
# <Axes: >

# %% [markdown]
# ##### predicted values X
# ##### Actual values y

# %% [markdown]
# # 2. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

print('Decision Tree Classifier')
# Create instance of model
Dtree = DecisionTreeClassifier()

# Pass training data into model
Dtree.fit(x_train, y_train)
# Out:
# Decision Tree Classifier
# DecisionTreeClassifier()

# %% [markdown]
# ## Model Evaluation
# ### Decision Tree Classifier

# %%
from sklearn.metrics import accuracy_score
# prediction from the model
y_pred_Dtree = Dtree.predict(x_test)
# Score It

print('Decision Tree Classifier')
# Accuracy
print('--'*30)
Dtree_accuracy = round(accuracy_score(y_test, y_pred_Dtree) * 100,2)
print('Accuracy', Dtree_accuracy,'%')
# Out:
# Decision Tree Classifier
# ------------------------------------------------------------
# Accuracy 97.86 %

# %% [markdown]
# ### Accuracy 98.66 %

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix
# Calculate precision and recall
precision = precision_score(y_test, y_pred_Dtree)
recall = recall_score(y_test, y_pred_Dtree)
Dtree_accuracy = round(accuracy_score(y_test, y_pred_Dtree) * 100,2)

# Print the results
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')

print("--"*30)
# Calculate confusion matrix
confusion = confusion_matrix(y_test, y_pred_Dtree)

sns.heatmap(confusion, annot=True, fmt="d")
# Out:
# Precision: 0.99
# Recall: 0.97
# ------------------------------------------------------------
# <Axes: >

# %% [markdown]
# # 3. RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

print('Random Forest Classifier')
# Create instance of model
rfc = RandomForestClassifier()

# Pass training data into model
rfc.fit(x_train, y_train)
# Out:
# Random Forest Classifier
# RandomForestClassifier()

# %% [markdown]
# ## Model Evaluation
# ### RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score
# prediction from the model
y_pred_rfc = rfc.predict(x_test)
# Score It

print('Random Forest Classifier')
# Accuracy
print('--'*30)
rfc_accuracy = round(accuracy_score(y_test, y_pred_rfc) * 100,2)
print('Accuracy', rfc_accuracy,'%')
# Out:
# Random Forest Classifier
# ------------------------------------------------------------
# Accuracy 97.33 %

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix
# Calculate precision and recall
precision = precision_score(y_test, y_pred_rfc)
recall = recall_score(y_test, y_pred_rfc)

# Print the results
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print("--"*30)
# Calculate confusion matrix
confusion = confusion_matrix(y_test, y_pred_rfc)
sns.heatmap(confusion, annot=True, fmt="d")
# Out:
# Precision: 0.97
# Recall: 0.98
# ------------------------------------------------------------
# <Axes: >

# %% [markdown]
# # 4. Gradient Bossting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

print('Gradient Boosting Classifier')
# Create instance of model
gbc = GradientBoostingClassifier()

# Pass training data into model
gbc.fit(x_train, y_train)
# Out:
# Gradient Boosting Classifier
# GradientBoostingClassifier()

# %% [markdown]
# ## Model Evaluation
# ### GradientBoostingClassifier

# %%
from sklearn.metrics import accuracy_score
# prediction from the model
y_pred_gbc = gbc.predict(x_test)
# Score It

print('Gradient Boosting Classifier')
# Accuracy
print('--'*30)
gbc_accuracy = round(accuracy_score(y_test, y_pred_gbc) * 100,2)
print('Accuracy', gbc_accuracy,'%')
# Out:
# Gradient Boosting Classifier
# ------------------------------------------------------------
# Accuracy 98.75 %

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix
# Calculate precision and recall
precision = precision_score(y_test, y_pred_gbc)
recall = recall_score(y_test, y_pred_gbc)

# Print the results
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print("--"*30)
# Calculate confusion matrix
confusion = confusion_matrix(y_test, y_pred_gbc)
sns.heatmap(confusion, annot=True, fmt="d")
# Out:
# Precision: 0.98
# Recall: 0.99
# ------------------------------------------------------------
# <Axes: >

# %%
# Sample model scores (replace these with your actual model scores)
model_scores = {
    "Logistic Regression": log_reg_accuracy,
    "Decision Tree Classifier": Dtree_accuracy,
    "Random Forest Classifier": rfc_accuracy,
    "Gradient Boosting Classifier": gbc_accuracy
}

# Sort the model scores in descending order based on their values (higher values first)
sorted_scores = sorted(model_scores.items(), key=lambda x: x[1], reverse=True)

# Display the ranking of the models
print("Model Rankings (Greater Values are better):")
for rank, (model_name, score) in enumerate(sorted_scores, start=1):
    print(f"{rank}. {model_name}: {score}")
# Out:
# Model Rankings (Greater Values are better):
# 1. Gradient Boosting Classifier: 98.75
# 2. Decision Tree Classifier: 97.86
# 3. Random Forest Classifier: 97.33
# 4. Logistic Regression: 83.96
